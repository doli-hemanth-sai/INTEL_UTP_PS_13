# %%
import os
import glob
from IPython.display import Image, display
from IPython import display
import matplotlib as plt
display.clear_output()

# %%
# !pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.57 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 5771.7/8062.4 GB disk)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="LEuhzZj2mytu1nCKZn53")
project = rf.workspace("ai-training-mevw9").project("parking-detection-mitok")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.2/76.2 kB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.2 MB/s eta 0:00:00
# ...
# ^C
# ERROR: Operation cancelled by user
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 3
#       1 get_ipython().system('pip install roboflow')
# ----> 3 from roboflow import Roboflow
#       4 rf = Roboflow(api_key="LEuhzZj2mytu1nCKZn53")
#       5 project = rf.workspace("ai-training-mevw9").project("parking-detection-mitok")
#
# ModuleNotFoundError: No module named 'roboflow'

# %%
# !pip install pyyaml

# %%
import yaml

# Load the YAML file
with open('/kaggle/input/parking-final/parking.yaml', 'r') as file:
    yaml_content = yaml.safe_load(file)

# Dump the content to a new YAML file
with open('/kaggle/working/Parking-Detection-2/data.yaml', 'w') as file:
    yaml.safe_dump(yaml_content, file)

# Check the dumped content
with open('/kaggle/working/Parking-Detection-2/data.yaml', 'r') as file:
    dumped_content = yaml.safe_load(file)
    print(dumped_content)

# %%
from ultralytics import YOLO
model=YOLO('yolov8n.pt')
model.train(data='/kaggle/working/Parking-Detection-2/data.yaml', epochs=200)

# %%
from ultralytics import YOLO
model=YOLO("/kaggle/input/parking_final_morning/pytorch/parking_final/1/parking_final.pt")
results=model.predict("/kaggle/input/parking-image/parking-in-philadelphia.jpg")
print(results)
# Out:
# image 1/1 /kaggle/input/parking-image/parking-in-philadelphia.jpg: 352x640 14 emptys, 17 occupieds, 10.0ms
# Speed: 3.4ms preprocess, 10.0ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'Empty', 1: 'Empty-Filled', 2: 'Filled', 3: 'empty', 4: 'occupied'}
# obb: None
# orig_img: array([[[ 25,  21,  20],
#         [ 26,  22,  21],
#         [ 27,  23,  22],
#         ...,
#         [118, 116, 115],
#         [127, 123, 122],
#         [115, 111, 110]],
#
#        [[ 26,  22,  21],
#         [ 26,  22,  21],
#         [ 26,  22,  21],
#         ...,
#         [116, 112, 111],
#         [124, 120, 119],
#         [114, 110, 109]],
#
#        [[ 26,  22,  21],
#         [ 26,  22,  21],
#         [ 26,  22,  21],
#         ...,
#         [119, 114, 113],
#         [117, 115, 114],
#         [111, 109, 108]],
#
# ...
